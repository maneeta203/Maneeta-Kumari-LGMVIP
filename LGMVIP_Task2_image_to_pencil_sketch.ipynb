# %% [markdown]
# <a href="https://colab.research.google.com/github/maneeta203/Maneeta-Kumari-LGMVIP-TASK1/blob/main/LGMVIP_Task2_image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LGM Virtual Internship Program October Batch 2022**

# %% [markdown]
# # **Task 2 : Image to Pencil Sketch**

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image=cv2.imread('/content/flower.jpg')
cv2_imshow(image)

# %% [markdown]
# ![Untitled (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Grey scale image

# %%
grey_image = cv2.cvtcolor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)

# %% [markdown]
# ![Untitled.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Inverted scale image[**Negative Image**]

# %%
inverted_image = cv2.bitwise_not(grey_image)
cv2_imshow(inverted_image)

# %% [markdown]
# ![Untitled (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Pencil sketch[ **Mixing grey scale image with inverted image**]

# %%
def pencil_sketch(x,y):
  return cv2.divide(x, 255-y, scale=256)
  pencil_sketch=pencil_sketch(grey_image, image_smoothing)
  cv2_imshow(pencil_sketch)

# %% [markdown]
# ![pencilsketchadjusted-7402580.jpeg](data:image/jpeg;base64,...)

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)

# %% [markdown]
# ![Untitled (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![pencilsketchadjusted-7402580.jpeg](data:image/jpeg;base64,...)
